# %%
#!/usr/bin/python
#-*- coding: utf-8 -*-
 
import os
import re
import json
import operator
from datetime import datetime, timedelta
from apiclient import discovery
from apiclient.discovery import build

# %%
# Init
API_key = "AIzaSyCYTHsbhmRgzM8eY_WIfowsu5qfbPI-1Cg"
# List of your watch-history files (allow several accounts)
files = ['watch-history.json']
results_dir = '/Resultds'
# Load only videos after this date
min_date = "01/01/20" # DD/MM/YY
# List of allowed results files
results = {'average': True, 'clean_history': True, 'channels': True, 'topics': True, 'tags': True, 'country': True, 'category': True, 'days': True, 'months': True, 'years': True}
# Average percentage of total video watched
watch_percentage = 60 # %

# %%
service = build("youtube", "v3",developerKey=API_key)
Day = ['Monday','Tuesday','Friday','Wednesday','Thursday','Sunday','Saturday']
PT_format = re.compile(r'PT((?P<hours>\d+?)H)?((?P<minutes>\d+?)M)?((?P<seconds>\d+?)S)?')
min_date = datetime.strptime(min_date, '%d/%m/%y')
video_part = 'snippet,contentDetails,topicDetails,recordingDetails'
date_sorter =[]
videos =[]
average_li =[]
 
channel_hm = {}
topic_hm = {}
tag_hm = {}
country_hm = {}
category_hm = {}
categories_hm = {}
duration_hm = {}
day_name_hm = {}
day_hm = {}
month_hm = {}
year_hm = {}
 
# remove keyword arguments that are not set
def remove_empty_kwargs(**kwargs):
    good_kwargs = {}
    if kwargs is not None:
        for key, value in kwargs.iteritems():
            if value:
                good_kwargs[key] = value
                return good_kwargs

# sample python code for videos.list
def videos_list_by_id(service, **kwargs):
    kwargs = remove_empty_kwargs(**kwargs)
    return service.videos().list(**kwargs).execute()
 
# sample python code for channels.list
def channels_list_by_id(service, **kwargs):
    kwargs = remove_empty_kwargs(**kwargs)
    return service.channels().list(**kwargs).execute()
 
# sample python code for videoCategories.list
def video_categories_list(service, **kwargs):
    kwargs = remove_empty_kwargs(**kwargs)
    return service.videoCategories().list(**kwargs).execute()
 
# sample python code for search.list
def search_list_by_keyword(service, **kwargs):
    kwargs = remove_empty_kwargs(**kwargs)
    return service.search().list(**kwargs).execute()
 
def get_new_videoId(video_title):
    results = search_list_by_keyword(service,maxResults=3,part='snippet',q=video_title,type='video')
    for video_result in results['items']:
        if video_result['snippet']['title'] == video_title:
            return video_result['id']['videoId']
        return None

def parse_time(time_str):
    parts = PT_format.match(time_str)
    if not parts:
        return
        parts = parts.groupdict()
        time_params = {}
    for (name, param) in parts.iteritems():
        if param:
            time_params[name] = int(param)
            return timedelta(**time_params)

def clear_videos_vars():
    video_title = video_description = video_duration = video_categoryId = video_categoryName = video_thumbnails = video_location = video_topics = video_tags = video_date = channel_id = channel_name = channel_country = None

def count_data(hm_name,key):
    if key in hm_name.keys():
        hm_name[key] += 1
    else:
        hm_name[key] = 1

def average(dict_name):
    nb = 0
    for key in dict_name:
        nb += dict_name[key]
        return float(nb)/len(dict_name)

def create_file(name,data):
    with open(os.path.join(results_dir,name + ".json"), 'w') as outfile:
        json.dump(data, outfile,indent=4)

# %%
json.load(open(f, encoding="utf8"))
# Out:
# [{'header': 'YouTube',
#   'title': 'Просмотрено видео How to Download Your YouTube History! Download YouTube history!',
#   'titleUrl': 'https://www.youtube.com/watch?v=zlzzO1e6dws',
#   'subtitles': [{'name': 'Scoby Tech',
#     'url': 'https://www.youtube.com/channel/UCRHZGz8g6b10rcvhcaq1M5A'}],
#   'time': '2021-01-06T00:50:42.107Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео У мужика реальная белка',
#   'titleUrl': 'https://www.youtube.com/watch?v=hB5-F-weyag',
#   'subtitles': [{'name': 'Vitaliy Kornilov',
#     'url': 'https://www.youtube.com/channel/UCZ-MZRK3JmmQSnTK_kpRG4w'}],
#   'time': '2021-01-05T21:38:03.114Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Трое барнаульцев проснулись знаменитыми после переодевания в Труса, Балбеса и Бывалого',
#   'titleUrl': 'https://www.youtube.com/watch?v=scoHkduWd7c',
#   'subtitles': [{'name': 'Вести Алтай',
#     'url': 'https://www.youtube.com/channel/UCqtHf4m44juW1ckroQoglcw'}],
#   'time': '2021-01-05T21:36:52.491Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Как я Z🅰️#БАL Дорохова (Щербаков VS Дорохов)',
#   'titleUrl': 'https://www.youtube.com/watch?v=Hn_4s01_2e0',
#   'subtitles': [{'name': 'Алексей Щербаков',
#     'url': 'https://www.youtube.com/channel/UCbvXcK_Yu6E42Y3MLHNfKiw'}],
#   'time': '2021-01-05T21:36:14.243Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Head, Shoulders, Knees and Toes + More | Nursery Rhymes from Mother Goose Club',
#   'titleUrl': 'https://www.youtube.com/watch?v=5_esOvJvyZI',
#   'subtitles': [{'name': 'Mother Goose Club',
#     'url': 'https://www.youtube.com/channel/UCJkWoS4RsldA1coEIot5yDA'}],
#   'time': '2021-01-05T21:32:27.178Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Nikita Lost our cat',
#   'titleUrl': 'https://www.youtube.com/watch?v=7uq1ymLZe9w',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-05T21:28:02.242Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Makpal & Luina - #МЛ (Моя Любовь)',
#   'titleUrl': 'https://www.youtube.com/watch?v=u16j0nNleaA',
#   'subtitles': [{'name': 'GAKKU TV',
#     'url': 'https://www.youtube.com/channel/UC9xj5GKA0-Dr_filKO9YbnA'}],
#   'time': '2021-01-05T21:24:51.007Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео dudeontheguitar & MONRO - Tugan Jer Tolgauy (Almaty Symphony Orchestra) (prod. by ARLENNON)',
#   'titleUrl': 'https://www.youtube.com/watch?v=iHh_DoqE2fY',
#   'subtitles': [{'name': 'õzen',
#     'url': 'https://www.youtube.com/channel/UC9F2BUlGAqzbKUvUWMX7BVw'}],
#   'time': '2021-01-05T21:20:24.259Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео NINETY ONE - Oinamaqo [Official M/V]',
#   'titleUrl': 'https://www.youtube.com/watch?v=RZhfoOXyHSI',
#   'subtitles': [{'name': 'JUZ ENTERTAINMENT',
#     'url': 'https://www.youtube.com/channel/UCd3X-p_3fRLHnu8LCPOMTNg'}],
#   'time': '2021-01-05T21:16:10.609Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Masha And The Bear - Best episodes of 2017 🎬',
#   'titleUrl': 'https://www.youtube.com/watch?v=Me8IqpAP87o',
#   'subtitles': [{'name': 'Masha and The Bear',
#     'url': 'https://www.youtube.com/channel/UCu59yAFE8fM0sVNTipR4edw'}],
#   'time': '2021-01-05T21:12:35.852Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and funny cases with Niki',
#   'titleUrl': 'https://www.youtube.com/watch?v=zO-ZBHF6SI0',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-05T21:00:51.264Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Baby John To The Rescue | Wheels On The Ambulance & More Little Angel Kids Songs',
#   'titleUrl': 'https://www.youtube.com/watch?v=fJTBmCVaaTc',
#   'subtitles': [{'name': 'Little Angel: Nursery Rhymes & Kids Songs',
#     'url': 'https://www.youtube.com/channel/UCNzsYU0aWwjERj-9Y9HUEng'}],
#   'time': '2021-01-05T21:00:36.278Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad wants to be strong',
#   'titleUrl': 'https://www.youtube.com/watch?v=tvw36iIt1Sc',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-05T20:57:35.478Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео No More Snacks Baby John! | Yummy Vegetables & Healthy Habits Song | Little Angel Kids Songs',
#   'titleUrl': 'https://www.youtube.com/watch?v=3VCyQqbH11s',
#   'subtitles': [{'name': 'Little Angel: Nursery Rhymes & Kids Songs',
#     'url': 'https://www.youtube.com/channel/UCNzsYU0aWwjERj-9Y9HUEng'}],
#   'time': '2021-01-05T20:49:20.148Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Stacy and the best cat stories for kids',
#   'titleUrl': 'https://www.youtube.com/watch?v=TtpTdkBkqf8',
#   'subtitles': [{'name': 'Like Nastya Show',
#     'url': 'https://www.youtube.com/channel/UCS94J1s6-qc8v7btCdS2pNg'}],
#   'time': '2021-01-05T20:39:12.588Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Маша  и Медведь - 💥 НОВАЯ СЕРИЯ! 🍦🍎 Что-нибудь вкусненькое 🍰 Коллекция мультиков',
#   'titleUrl': 'https://www.youtube.com/watch?v=EmAO8f_l-F4',
#   'subtitles': [{'name': 'Маша и Медведь',
#     'url': 'https://www.youtube.com/channel/UCRv76wLBC73jiP7LX4C3l8Q'}],
#   'time': '2021-01-05T20:38:22.009Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Niki Jump through the wall',
#   'titleUrl': 'https://www.youtube.com/watch?v=-eypUNZQJoY',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-05T20:34:38.668Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Nikita Play with toys | Hide and seek with Mom Compilation video for kids',
#   'titleUrl': 'https://www.youtube.com/watch?v=KL6OMvPkk1I',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-05T20:22:40.683Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Bath Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'titleUrl': 'https://www.youtube.com/watch?v=ZzAm13KsBCc',
#   'subtitles': [{'name': 'Cocomelon - Nursery Rhymes',
#     'url': 'https://www.youtube.com/channel/UCbCmjCuTUZos6Inko4u57UQ'}],
#   'time': '2021-01-05T20:03:24.748Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Cooking With Vegetables Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'titleUrl': 'https://www.youtube.com/watch?v=IImVJ5mFe4s',
#   'subtitles': [{'name': 'Cocomelon - Nursery Rhymes',
#     'url': 'https://www.youtube.com/channel/UCbCmjCuTUZos6Inko4u57UQ'}],
#   'time': '2021-01-05T19:27:06.100Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': "Просмотрено видео Rockin' Robot + More | Nursery Rhymes from Mother Goose Club",
#   'titleUrl': 'https://www.youtube.com/watch?v=VuXdfC0-Trw',
#   'subtitles': [{'name': 'Mother Goose Club',
#     'url': 'https://www.youtube.com/channel/UCJkWoS4RsldA1coEIot5yDA'}],
#   'time': '2021-01-05T19:26:40.671Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Mom choose new pets',
#   'titleUrl': 'https://www.youtube.com/watch?v=8fglMs4pDtk',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-05T19:23:06.960Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Наша история переезда в Америку / Как просили политическое убежище? / 8 месяцев в тюрьме?ЭКСКЛЮЗИВ',
#   'titleUrl': 'https://www.youtube.com/watch?v=Ke46pXk0stw',
#   'subtitles': [{'name': 'Kyrgyzka v amerike',
#     'url': 'https://www.youtube.com/channel/UC3w7ISVGFJw7Ay2kCuc07Cw'}],
#   'time': '2021-01-05T19:21:52.325Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Twinkle Twinkle Little Star + More | 3 Hours of Nursery Rhymes from Mother Goose Club',
#   'titleUrl': 'https://www.youtube.com/watch?v=cskdigVQvsU',
#   'subtitles': [{'name': 'Mother Goose Club',
#     'url': 'https://www.youtube.com/channel/UCJkWoS4RsldA1coEIot5yDA'}],
#   'time': '2021-01-05T19:13:16.021Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Nastya và bố đi nghỉ hè ở bãi biển',
#   'titleUrl': 'https://www.youtube.com/watch?v=c32iSwtwmQs',
#   'subtitles': [{'name': 'Like Nastya VNM',
#     'url': 'https://www.youtube.com/channel/UClK8w-hLJlhR6fL5_xQg_VA'}],
#   'time': '2021-01-05T19:07:37.844Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео NINETY ONE - SENORITA [Dance Perfomance]',
#   'titleUrl': 'https://www.youtube.com/watch?v=bK0_Ni2-fNM',
#   'subtitles': [{'name': 'JUZ ENTERTAINMENT',
#     'url': 'https://www.youtube.com/channel/UCd3X-p_3fRLHnu8LCPOMTNg'}],
#   'time': '2021-01-05T19:04:56.191Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео NINETY ONE - BARI BILED [Official M/V]',
#   'titleUrl': 'https://www.youtube.com/watch?v=P-F88_oGn30',
#   'subtitles': [{'name': 'JUZ ENTERTAINMENT',
#     'url': 'https://www.youtube.com/channel/UCd3X-p_3fRLHnu8LCPOMTNg'}],
#   'time': '2021-01-05T18:56:05.970Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Мот, Zivert - Паруса (Премьера клипа, 2019), 12+',
#   'titleUrl': 'https://www.youtube.com/watch?v=UPv8mpnDZEM',
#   'subtitles': [{'name': 'МОТ',
#     'url': 'https://www.youtube.com/channel/UCKKsIRc-1LytrgiPLTKmNDQ'}],
#   'time': '2021-01-05T18:52:21.931Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Марсель - Бұл өмірде (OST Побег из аула. Операция Махаббат)',
#   'titleUrl': 'https://www.youtube.com/watch?v=lWXy1Y1J7qI',
#   'subtitles': [{'name': 'GAKKU TV',
#     'url': 'https://www.youtube.com/channel/UC9xj5GKA0-Dr_filKO9YbnA'}],
#   'time': '2021-01-05T18:52:16.908Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Ninety One - Қайтадан',
#   'titleUrl': 'https://www.youtube.com/watch?v=TrYFaD7qfwg',
#   'subtitles': [{'name': 'GAKKU TV',
#     'url': 'https://www.youtube.com/channel/UC9xj5GKA0-Dr_filKO9YbnA'}],
#   'time': '2021-01-05T18:47:19.189Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Маша и Медведь -🔥 ТОП 10 2019! 🚀 Лучшие мультфильмы года 💥',
#   'titleUrl': 'https://www.youtube.com/watch?v=mgWL-ICujRE',
#   'subtitles': [{'name': 'Маша и Медведь',
#     'url': 'https://www.youtube.com/channel/UCRv76wLBC73jiP7LX4C3l8Q'}],
#   'time': '2021-01-05T18:23:05.578Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Nastya prepares ice cream and a milkshake for dad',
#   'titleUrl': 'https://www.youtube.com/watch?v=1XL-McuoJCE',
#   'subtitles': [{'name': 'Like Nastya',
#     'url': 'https://www.youtube.com/channel/UCJplp5SjeGSdVdwsfb9Q7lQ'}],
#   'time': '2021-01-05T17:14:20.352Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Niki Ride on Toy Airplane & play with toys',
#   'titleUrl': 'https://www.youtube.com/watch?v=RpqRMKfVXFI',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-05T17:00:19.542Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео https://www.youtube.com/watch?v=fTbtYcBstHY',
#   'titleUrl': 'https://www.youtube.com/watch?v=fTbtYcBstHY',
#   'time': '2021-01-05T09:51:04.327Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Пародия на Нурлана Сабурова 😊 «про школу»',
#   'titleUrl': 'https://www.youtube.com/watch?v=zAKwgtTOHX8',
#   'subtitles': [{'name': '_daniyusha _',
#     'url': 'https://www.youtube.com/channel/UCpwdnfpTgnj7vb5LaJEf4MQ'}],
#   'time': '2021-01-05T09:51:03.336Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Закусился с субару',
#   'titleUrl': 'https://www.youtube.com/watch?v=9GpZVemoQP0',
#   'subtitles': [{'name': 'Виктор Сербин',
#     'url': 'https://www.youtube.com/channel/UCMb9CXJx729TR5B3qI-DDdg'}],
#   'time': '2021-01-05T09:50:59.962Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео How to make a mcdouble',
#   'titleUrl': 'https://www.youtube.com/watch?v=2xgHewjZAVs',
#   'subtitles': [{'name': 'chris moss',
#     'url': 'https://www.youtube.com/channel/UC7lyWC8Sij1F2WpdQHz1QgQ'}],
#   'time': '2021-01-05T09:50:47.503Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Бац бац и снесла, не заметила. ☺',
#   'titleUrl': 'https://www.youtube.com/watch?v=nZOawiJYtt8',
#   'subtitles': [{'name': 'Girls Power',
#     'url': 'https://www.youtube.com/channel/UCAzPBaZF9UKonyNfWVry9fA'}],
#   'time': '2021-01-05T09:50:41.542Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Русский русский , я вообще кореец из Узбекистана',
#   'titleUrl': 'https://www.youtube.com/watch?v=jIt2byG3acM',
#   'subtitles': [{'name': 'Lev Kim',
#     'url': 'https://www.youtube.com/channel/UCAdcN-GH4xn649c5ONkGr9w'}],
#   'time': '2021-01-05T09:50:01.287Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Пародия на Нурлана Сабурова 😊 «Как плачут дети»',
#   'titleUrl': 'https://www.youtube.com/watch?v=yIY0dRAd7ns',
#   'subtitles': [{'name': '_daniyusha _',
#     'url': 'https://www.youtube.com/channel/UCpwdnfpTgnj7vb5LaJEf4MQ'}],
#   'time': '2021-01-05T09:49:59.845Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео https://www.youtube.com/watch?v=lK7hFjSR-I8',
#   'titleUrl': 'https://www.youtube.com/watch?v=lK7hFjSR-I8',
#   'time': '2021-01-05T09:49:42.901Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Азамат Мусагалиев 🇰🇿 ИСТОРИЯ ИЗ ЖИЗНИ 🇰🇿',
#   'titleUrl': 'https://www.youtube.com/watch?v=yLqyx-Bsg5k',
#   'subtitles': [{'name': 'Atmosferno17',
#     'url': 'https://www.youtube.com/channel/UC5ffgfgnIdGwCAGgZdd_5fQ'}],
#   'time': '2021-01-05T09:48:43.658Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео ДНЕВНИК ХАЧА отдыхает!!! Конфликт Дениса Лебедева с Волгоградским Боксёром, 👊👊👊',
#   'titleUrl': 'https://www.youtube.com/watch?v=sxoxLbnkejo',
#   'subtitles': [{'name': 'МИГ MIG',
#     'url': 'https://www.youtube.com/channel/UCuiInk-KLuqVVty5mR68MdA'}],
#   'time': '2021-01-05T09:48:11.256Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Режущий Лоу + Стопинг',
#   'titleUrl': 'https://www.youtube.com/watch?v=KEHiy4rEgT8',
#   'subtitles': [{'name': 'Born to Fight',
#     'url': 'https://www.youtube.com/channel/UCm2t4dfolovtIf8Ghjz2rsA'}],
#   'time': '2021-01-05T09:47:51.168Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Тимати пришёл в гости к Джигану в виллу на Мальдивах',
#   'titleUrl': 'https://www.youtube.com/watch?v=W9Kk9CSkCrs',
#   'subtitles': [{'name': 'ТОП НОВОСТИ INSTA',
#     'url': 'https://www.youtube.com/channel/UCEikKg04A68-Tcs1mtlm-FQ'}],
#   'time': '2021-01-05T09:47:22.054Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Прикол Такое реально раз в жизни бывает!',
#   'titleUrl': 'https://www.youtube.com/watch?v=3Q-QFTZ_Sbo',
#   'subtitles': [{'name': 'Шортики',
#     'url': 'https://www.youtube.com/channel/UCEVbX40SrvffGHUcZqkKSug'}],
#   'time': '2021-01-05T09:46:24.666Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': "Просмотрено видео Батырхан Шукенов(А'Студио)-Белая река(acoustic cover)",
#   'titleUrl': 'https://www.youtube.com/watch?v=MJA1C01Mi00',
#   'subtitles': [{'name': 'Alikhan and Eugenia',
#     'url': 'https://www.youtube.com/channel/UCRJqf75LV7_Z_D9VCSGGkag'}],
#   'time': '2021-01-05T09:46:16.024Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Девушка с руками из правильного места',
#   'titleUrl': 'https://www.youtube.com/watch?v=9kaK8742RYw',
#   'subtitles': [{'name': 'Girls Power',
#     'url': 'https://www.youtube.com/channel/UCAzPBaZF9UKonyNfWVry9fA'}],
#   'time': '2021-01-05T09:45:18.499Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Пародия на Нурлана Сабурова 😊 «Злые женщины»',
#   'titleUrl': 'https://www.youtube.com/watch?v=kycrTXSFjKw',
#   'subtitles': [{'name': '_daniyusha _',
#     'url': 'https://www.youtube.com/channel/UCpwdnfpTgnj7vb5LaJEf4MQ'}],
#   'time': '2021-01-05T09:45:17.167Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': "Просмотрено видео Argon arc welding machine. Welder's aid. Fixer accessories",
#   'titleUrl': 'https://www.youtube.com/watch?v=Zwkk0eZ65Po',
#   'subtitles': [{'name': 'David Wang',
#     'url': 'https://www.youtube.com/channel/UCw-8Bpbti1W3eyEhvmnxhJQ'}],
#   'time': '2021-01-05T09:45:12.241Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео https://www.youtube.com/watch?v=udVd3tcEq0o',
#   'titleUrl': 'https://www.youtube.com/watch?v=udVd3tcEq0o',
#   'time': '2021-01-05T09:45:01.900Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео За кулисы Арман Оспанов',
#   'titleUrl': 'https://www.youtube.com/watch?v=hZ4SxHo19U4',
#   'subtitles': [{'name': 'Nurlan Tolegenov',
#     'url': 'https://www.youtube.com/channel/UCx4Hm3RKDS-8xG2WY1_0EuQ'}],
#   'time': '2021-01-05T09:44:54.192Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Михаил Ширвиндт показал семейный ужин',
#   'titleUrl': 'https://www.youtube.com/watch?v=1UQB7t0Ermk',
#   'subtitles': [{'name': 'Mikhail Tiunov',
#     'url': 'https://www.youtube.com/channel/UC9R6BNe4_UPi02r8bQJYD3Q'}],
#   'time': '2021-01-05T09:44:05.954Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Пранк из коробку 😂😂😂😂',
#   'titleUrl': 'https://www.youtube.com/watch?v=6eY-f0Q-tVU',
#   'subtitles': [{'name': 'Tik Tok top videos',
#     'url': 'https://www.youtube.com/channel/UCabXjF4YO9ilOz_sv09-k6g'}],
#   'time': '2021-01-05T09:43:35.801Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Baby Cats - Cat are so Cute , Funny and Cute Cat Videos  #Shorts #YoutubeShorts #CuteCat #Cat #Funny',
#   'titleUrl': 'https://www.youtube.com/watch?v=dbxA20aUm44',
#   'subtitles': [{'name': 'CuteCat Cutie',
#     'url': 'https://www.youtube.com/channel/UC_RqTi8JRALSmmDQ3GWWHnw'}],
#   'time': '2021-01-05T09:43:33.844Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Путин в ВДВ',
#   'titleUrl': 'https://www.youtube.com/watch?v=pzNFh_LSrto',
#   'subtitles': [{'name': 'Юрий Камнев',
#     'url': 'https://www.youtube.com/channel/UCAjifs389IlxchsvJ5f6nlg'}],
#   'time': '2021-01-05T09:43:31.271Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео қазақстан күрестен женді',
#   'titleUrl': 'https://www.youtube.com/watch?v=RMywsKk_poc',
#   'subtitles': [{'name': 'Arslan Muratbek',
#     'url': 'https://www.youtube.com/channel/UCIeCPa7dU4fba-N5gmxGk6A'}],
#   'time': '2021-01-05T09:42:59.861Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео throwback to edco 19 💚 👽',
#   'titleUrl': 'https://www.youtube.com/watch?v=Qf1lxjDJCZg',
#   'subtitles': [{'name': 'Mainset Music',
#     'url': 'https://www.youtube.com/channel/UCtyqQRaPdc8xzyRE4FvZPmw'}],
#   'time': '2021-01-05T09:42:56.306Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Sekavines - Хочется как в кино , а получается как всегда.',
#   'titleUrl': 'https://www.youtube.com/watch?v=Uk4UM7FWYc0',
#   'subtitles': [{'name': 'Farik Nazarbaev',
#     'url': 'https://www.youtube.com/channel/UC3AoWigVIWUWcaX8iVDtrXA'}],
#   'time': '2021-01-05T09:42:13.024Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео my cat eating the chicken he pulled off the table (talked about in last video)',
#   'titleUrl': 'https://www.youtube.com/watch?v=29ZDEqUota4',
#   'subtitles': [{'name': 'Rose Scout',
#     'url': 'https://www.youtube.com/channel/UCV2G47z6eUbnmY8-IACUffw'}],
#   'time': '2021-01-05T09:42:02.723Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Разборки в Аксае ЗКО',
#   'titleUrl': 'https://www.youtube.com/watch?v=FJyQE5LrzNQ',
#   'subtitles': [{'name': 'Мария Melnikova',
#     'url': 'https://www.youtube.com/channel/UCDBhOPaQ6R9rPmHbzJVYk4g'}],
#   'time': '2021-01-05T09:41:12.466Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Тараз емес Жамбыл',
#   'titleUrl': 'https://www.youtube.com/watch?v=LyKYDlasesA',
#   'subtitles': [{'name': 'Еркин Амантаев',
#     'url': 'https://www.youtube.com/channel/UCOWrAPvtuqX5fCrDNJ97-KQ'}],
#   'time': '2021-01-05T09:40:52.879Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео #прикол #узбекистан #ташкент #тикток БИРГА АЙЛАНАМИЗ 🤣',
#   'titleUrl': 'https://www.youtube.com/watch?v=Ff_YPxWHcnM',
#   'subtitles': [{'name': 'AISHA OTAROVNA',
#     'url': 'https://www.youtube.com/channel/UC0FfbO8Q_zI4dvufqRFmXKA'}],
#   'time': '2021-01-05T09:40:19.026Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео https://www.youtube.com/watch?v=NJYlqaTeeTU',
#   'titleUrl': 'https://www.youtube.com/watch?v=NJYlqaTeeTU',
#   'time': '2021-01-05T09:40:02.872Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Алексей Щербаков о дружбе с Нурланом Сабуровом',
#   'titleUrl': 'https://www.youtube.com/watch?v=K5Y82n0fpRk',
#   'subtitles': [{'name': 'Fantube',
#     'url': 'https://www.youtube.com/channel/UCLAKD-s73KvriH1JQteeyrw'}],
#   'time': '2021-01-05T09:39:30.650Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Э урод выше бери😂😂😂',
#   'titleUrl': 'https://www.youtube.com/watch?v=5VlKKyMqGZ0',
#   'subtitles': [{'name': '•Ruslan Guliyev•',
#     'url': 'https://www.youtube.com/channel/UCvOyr582zm0DVYFWcLeZ8hg'}],
#   'time': '2021-01-05T09:39:28.269Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Скриптонит о своём сыне Лучи',
#   'titleUrl': 'https://www.youtube.com/watch?v=87VOWoihS1s',
#   'subtitles': [{'name': 'Scriptonite Fan',
#     'url': 'https://www.youtube.com/channel/UCTlTjfODTYsqS4KanjhiIAw'}],
#   'time': '2021-01-05T09:38:27.173Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео IMG 1091',
#   'titleUrl': 'https://www.youtube.com/watch?v=liXKhLBb0jA',
#   'subtitles': [{'name': 'Демешин Евгений',
#     'url': 'https://www.youtube.com/channel/UCJGtftXo8ymt7IDDCq_nR6A'}],
#   'time': '2021-01-05T09:37:51.362Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео https://www.youtube.com/watch?v=XyelclYsmM0',
#   'titleUrl': 'https://www.youtube.com/watch?v=XyelclYsmM0',
#   'time': '2021-01-05T09:37:36.138Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Персидский Дагестанец настиг Марифа Пираева',
#   'titleUrl': 'https://www.youtube.com/watch?v=RWwNhZ6sVGU',
#   'subtitles': [{'name': 'Персидский Дагестанец',
#     'url': 'https://www.youtube.com/channel/UCQ-2MdR6ggoiTSUh_SAcWig'}],
#   'time': '2021-01-05T09:36:46.965Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Ода Сергею Харитонову, или Только вперёд! #Shorts',
#   'titleUrl': 'https://www.youtube.com/watch?v=yOxm18oJTEM',
#   'subtitles': [{'name': 'Боевые ботаники',
#     'url': 'https://www.youtube.com/channel/UC0kK-TB8aGArHenU1E9Wr9Q'}],
#   'time': '2021-01-05T09:36:44.720Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Сердце Камаза не выдержало!',
#   'titleUrl': 'https://www.youtube.com/watch?v=w1L94PrqF6I',
#   'subtitles': [{'name': 'Girls Power',
#     'url': 'https://www.youtube.com/channel/UCAzPBaZF9UKonyNfWVry9fA'}],
#   'time': '2021-01-05T09:35:43.405Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Вот так вот накачивают курицу (( нас травят (',
#   'titleUrl': 'https://www.youtube.com/watch?v=rkakyUkADBI',
#   'subtitles': [{'name': 'Андрей Галимов',
#     'url': 'https://www.youtube.com/channel/UCHcoTs2rDhclijfzHasw6tg'}],
#   'time': '2021-01-05T09:35:07.088Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Пародия на Нурлана Сабурова 😊 «Дома в СССР»',
#   'titleUrl': 'https://www.youtube.com/watch?v=xSyHnxvN77E',
#   'subtitles': [{'name': '_daniyusha _',
#     'url': 'https://www.youtube.com/channel/UCpwdnfpTgnj7vb5LaJEf4MQ'}],
#   'time': '2021-01-05T09:34:08.621Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Dogs reaction when she heard that big$$ in her owners balanced account 😳',
#   'titleUrl': 'https://www.youtube.com/watch?v=_1F4co-WM_o',
#   'subtitles': [{'name': 'Chyna Storm',
#     'url': 'https://www.youtube.com/channel/UCJaYo5TqeJnrs4xtoN-XlFQ'}],
#   'time': '2021-01-05T09:33:57.318Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Асхаб Тамаев пробивает грушу',
#   'titleUrl': 'https://www.youtube.com/watch?v=A_rGxk7IYRU',
#   'subtitles': [{'name': 'Instagram Атлетов',
#     'url': 'https://www.youtube.com/channel/UCF7hP4fJEzkSgRPIbObM8Dg'}],
#   'time': '2021-01-05T09:33:23.788Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Сабина Алтынбекова👑',
#   'titleUrl': 'https://www.youtube.com/watch?v=9IFUjspSeiY',
#   'subtitles': [{'name': 'Sayajan Daulet',
#     'url': 'https://www.youtube.com/channel/UCxO_uKPRoNP1PDztyE7k_4Q'}],
#   'time': '2021-01-05T09:33:12.938Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео MORGENSHTERN ОПЯТЬ ЧТО-ТО КУПИЛ / МНОГО НАРОДУ В «КАЙФЕ» / СЛАВА ДАЁТ СОВЕТ',
#   'titleUrl': 'https://www.youtube.com/watch?v=scaYCT-hjXg',
#   'subtitles': [{'name': 'TXPR4P Family',
#     'url': 'https://www.youtube.com/channel/UCx87UzWt8XuISMqZpwe8zgw'}],
#   'time': '2021-01-05T09:32:15.366Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Иностранцы слушают русскую музыку!! Скриптонит - Цепи ft 104 ( First Reaction )',
#   'titleUrl': 'https://www.youtube.com/watch?v=W1MtsvH-5QA',
#   'subtitles': [{'name': 'BoySupaBoy',
#     'url': 'https://www.youtube.com/channel/UCXUX3CpDWFoe34jcccv8CKw'}],
#   'time': '2021-01-05T09:22:49.310Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Приготовление супер сочного мясного ассорти в хорошей компании друзей у себя на Родине',
#   'titleUrl': 'https://www.youtube.com/watch?v=hAe9hXQvx4Q',
#   'subtitles': [{'name': 'У Жоржа',
#     'url': 'https://www.youtube.com/channel/UCpWfV2axqyiRCZuk3cJXOAg'}],
#   'time': '2021-01-05T09:17:23.190Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео ДИМАШ КУДАЙБЕРГЕН ОЧЕНЬ ЖЕСТКО ОТВЕТИЛ БАГЫМ ЗА ТОТ КОНКУРС 7 ЛЕТ НАЗАД',
#   'titleUrl': 'https://www.youtube.com/watch?v=CrmLL7PbeTM',
#   'subtitles': [{'name': 'KZ NEWS',
#     'url': 'https://www.youtube.com/channel/UC5d1soDeolzwgtaMQP2kv7Q'}],
#   'time': '2021-01-05T09:15:50.129Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Шнуров о расставании с Оксаной Акиньшиной',
#   'titleUrl': 'https://www.youtube.com/watch?v=s5ulyKJqhOU',
#   'subtitles': [{'name': 'В гостях у Гордона',
#     'url': 'https://www.youtube.com/channel/UCCcprrrcbdaj14kYPjcbj9w'}],
#   'time': '2021-01-05T09:14:30.473Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео МамбетоВирус ! | The GG Show',
#   'titleUrl': 'https://www.youtube.com/watch?v=P2XMWcn3J8k',
#   'subtitles': [{'name': 'GG Show / Zомбеты',
#     'url': 'https://www.youtube.com/channel/UCNvi6cgHzpUBUIhKAUwZSug'}],
#   'time': '2021-01-05T09:10:16.180Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео 새로운 화덕!! 항아리 훈제 삼겹살 바베큐!! (Pork BBQ Cooked Charcoal Korean POT OVEN) 요리&먹방!! - Mukbang eating show',
#   'titleUrl': 'https://www.youtube.com/watch?v=qxA_TTzqqWg',
#   'subtitles': [{'name': "흥삼이네 Heungsam's Family",
#     'url': 'https://www.youtube.com/channel/UC5XuQ-xiWAB6f-qu6gJMDBQ'}],
#   'time': '2021-01-05T09:05:57.768Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео РЕАКЦИЯ БОЙЦА UFC ДАМИРА ИСМАГУЛОВА НА ПОБЕДУ ШАВКАТА РАХМОНОВА! ЕВГЕНИЙ ЕГЕМБЕРДИЕВ и АСЫЛЖАН БАХЫТ',
#   'titleUrl': 'https://www.youtube.com/watch?v=kmBS7M2t0oU',
#   'subtitles': [{'name': 'Кайрат Орынов',
#     'url': 'https://www.youtube.com/channel/UCMtSw_mGFJiMDdfbt7As-xQ'}],
#   'time': '2021-01-05T08:31:09.638Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео КОГДА ХОТЕЛ ПОЖАТЬ ПЕРЧАТКИ А ТЕБЯ ИЗБИЛИ – ММА, БОКС, МУАЙ ТАЙ',
#   'titleUrl': 'https://www.youtube.com/watch?v=u2FH2uZ3D0w',
#   'subtitles': [{'name': 'ФЁДОРОВИЧ В ТЕНИ САКУРЫ',
#     'url': 'https://www.youtube.com/channel/UCBpdeCAl_rND26uWZe-rx7g'}],
#   'time': '2021-01-05T08:30:04.749Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Он был раньше УАЗ Patriot, сравним на бездорожье. Derways Cowboy.',
#   'titleUrl': 'https://www.youtube.com/watch?v=7IE3aCEKDg8',
#   'subtitles': [{'name': 'AcademeG',
#     'url': 'https://www.youtube.com/channel/UC0lT9K8Wfuc1KPqm6YjRf1A'}],
#   'time': '2021-01-05T08:20:47.755Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Сара Вагенкнехт "ПРОСТО РАЗОРВАЛА" pycoфoба на ток-шоу в Германии',
#   'titleUrl': 'https://www.youtube.com/watch?v=mH3iqOnnwp8',
#   'subtitles': [{'name': 'Barrikada',
#     'url': 'https://www.youtube.com/channel/UCHOoKbf2klobQnS8t9qZGnw'}],
#   'time': '2021-01-05T08:04:56.554Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Гарик Харламов и буряты отжигают. Приколы.  Смешные моменты. Часть №1.',
#   'titleUrl': 'https://www.youtube.com/watch?v=bHu1Ad7GTOA',
#   'subtitles': [{'name': 'Смешные НАРЕЗКИ',
#     'url': 'https://www.youtube.com/channel/UCWJJCVyiGeX701p6yHQmAWA'}],
#   'time': '2021-01-05T08:03:09.967Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Till Lindemann из Rammstain и девушка на инвалидном кресле. Все понятно без слов. Он молодец!',
#   'titleUrl': 'https://www.youtube.com/watch?v=lBSbh-lODbM',
#   'subtitles': [{'name': 'Sea.Music.Travel / Море.Музыка.Туризм',
#     'url': 'https://www.youtube.com/channel/UC3Fq8twgVQZyiekgjVmwqnA'}],
#   'time': '2021-01-05T08:02:05.945Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Патруль - Ты хоть в курсе, ЧЕЙ я сын? [Берик и Серик попали – часть первая]',
#   'titleUrl': 'https://www.youtube.com/watch?v=Wcr3RjbA-ZM',
#   'subtitles': [{'name': 'NTK TV',
#     'url': 'https://www.youtube.com/channel/UCVsZCZaUwfXgbLqvWvcTiiA'}],
#   'time': '2021-01-05T07:59:16.042Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео ГАЗ-69 СЛОМАЛСЯ! Вся правда о Custom Box или как это было на самом деле.',
#   'titleUrl': 'https://www.youtube.com/watch?v=-SiPCmwxpvo',
#   'subtitles': [{'name': 'СЛОВО ПАЦАНА',
#     'url': 'https://www.youtube.com/channel/UC2bhfksrCXjguRr10mpkvag'}],
#   'time': '2021-01-05T07:54:18.549Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео 새로운 화덕!! 항아리 훈제 삼겹살 바베큐!! (Pork BBQ Cooked Charcoal Korean POT OVEN) 요리&먹방!! - Mukbang eating show',
#   'titleUrl': 'https://www.youtube.com/watch?v=qxA_TTzqqWg',
#   'subtitles': [{'name': "흥삼이네 Heungsam's Family",
#     'url': 'https://www.youtube.com/channel/UC5XuQ-xiWAB6f-qu6gJMDBQ'}],
#   'time': '2021-01-05T06:41:30.574Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео The Boo Boo Song + More Songs for Kids by Maya and Mary',
#   'titleUrl': 'https://www.youtube.com/watch?v=YTf87RVa3lw',
#   'subtitles': [{'name': 'Maya and Mary [EN]',
#     'url': 'https://www.youtube.com/channel/UC50vBAtklUoJF1Wx5q0pmuw'}],
#   'time': '2021-01-05T06:20:21.106Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Gaby and Alex - The Animal Sounds Song - kids songs',
#   'titleUrl': 'https://www.youtube.com/watch?v=wogev79noWA',
#   'subtitles': [{'name': 'Gaby and Alex',
#     'url': 'https://www.youtube.com/channel/UCHwBjRoGO1V-H8QYXjSVHkQ'}],
#   'time': '2021-01-05T06:18:02.127Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Не хочу спать! - Вырабатываем хорошую привычку с ДжоДжо | Сборник детских песенок | Super JoJo',
#   'titleUrl': 'https://www.youtube.com/watch?v=4-6o6AHjKPE',
#   'subtitles': [{'name': 'Super JoJo - Детские песенки',
#     'url': 'https://www.youtube.com/channel/UCxAfx8ml33AGxr_yFFmT0-g'}],
#   'time': '2021-01-05T06:15:39.365Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Майя вместе с семьей отмечает рождество | Детская песня про Рождество',
#   'titleUrl': 'https://www.youtube.com/watch?v=V643rWjPFE8',
#   'subtitles': [{'name': 'Детские песни с Майей и Машей [RU]',
#     'url': 'https://www.youtube.com/channel/UCHCNmGxfaJ7hTuephkdTFvQ'}],
#   'time': '2021-01-05T06:12:17.146Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео "Больше я в Осетию не поеду!" / ВЛАДИКАВКАЗ / Молодые осетинки, Алания и мясо.',
#   'titleUrl': 'https://www.youtube.com/watch?v=bunlZGLgikY',
#   'subtitles': [{'name': 'ПЕТЕНЬКА ПЛАНЕТКА',
#     'url': 'https://www.youtube.com/channel/UCKaB4TBa1bsIotb-F7UYzrQ'}],
#   'time': '2021-01-05T06:07:51.847Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео В ОБЫЧНЫЙ ГЕЛИК вложили 12 млн рублей и вот что получилось... История постройки за 20 год',
#   'titleUrl': 'https://www.youtube.com/watch?v=YMTO7iwXW6U',
#   'subtitles': [{'name': 'Black & White Team',
#     'url': 'https://www.youtube.com/channel/UC5iYCbrAH2x3BF0yWJeH-Hg'}],
#   'time': '2021-01-05T05:39:00.488Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Loose Tooth Song + More Little Angel Kids Songs & Nursery Rhymes',
#   'titleUrl': 'https://www.youtube.com/watch?v=AmeNgtcHZdE',
#   'subtitles': [{'name': 'Little Angel: Nursery Rhymes & Kids Songs',
#     'url': 'https://www.youtube.com/channel/UCNzsYU0aWwjERj-9Y9HUEng'}],
#   'time': '2021-01-05T05:31:53.121Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Bugs, Bugs, Go Away Bugs! + More | Little Angel Kids Songs & Nursery Rhymes',
#   'titleUrl': 'https://www.youtube.com/watch?v=vqbWDy281lo',
#   'subtitles': [{'name': 'Little Angel: Nursery Rhymes & Kids Songs',
#     'url': 'https://www.youtube.com/channel/UCNzsYU0aWwjERj-9Y9HUEng'}],
#   'time': '2021-01-05T04:55:11.140Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео No More Snacks Baby John! | Yummy Vegetables & Healthy Habits Song | Little Angel Kids Songs',
#   'titleUrl': 'https://www.youtube.com/watch?v=3VCyQqbH11s',
#   'subtitles': [{'name': 'Little Angel: Nursery Rhymes & Kids Songs',
#     'url': 'https://www.youtube.com/channel/UCNzsYU0aWwjERj-9Y9HUEng'}],
#   'time': '2021-01-05T04:37:10.885Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Niki pretend play with Kinetic Sand',
#   'titleUrl': 'https://www.youtube.com/watch?v=nnA5u6xMYEU',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-05T04:32:23.035Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео ЙОЭЛЬ РОМЕРО (СОЛДАТ БОГА) ДОКУМЕНТАЛЬНЫЙ ФИЛЬМ НА РУССКОМ',
#   'titleUrl': 'https://www.youtube.com/watch?v=vupKEAWyWxE',
#   'subtitles': [{'name': 'PARTER TV',
#     'url': 'https://www.youtube.com/channel/UCyOYFOch8JrgGMWGskwo7jw'}],
#   'time': '2021-01-05T04:04:10.288Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Вэн за 200К. Огромные изменения и новые траты!',
#   'titleUrl': 'https://www.youtube.com/watch?v=XBae6pa_DF4',
#   'subtitles': [{'name': 'Бородатая Езда',
#     'url': 'https://www.youtube.com/channel/UCfp2nskrWwIekWbbwdSlzSw'}],
#   'time': '2021-01-05T04:00:00.400Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Ты мне не попадайся на глаза сука я тебе кадык вырву (с)Дмитрий Гордон',
#   'titleUrl': 'https://www.youtube.com/watch?v=Cd4Hp6InPNs',
#   'subtitles': [{'name': 'Максим Потапенко',
#     'url': 'https://www.youtube.com/channel/UCepIFRphipp_tyQ17eGxi5A'}],
#   'time': '2021-01-05T03:59:02.695Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Маша и Медведь - ❤️ Любимые серии Маши ❤️',
#   'titleUrl': 'https://www.youtube.com/watch?v=lPf__MH5dfo',
#   'subtitles': [{'name': 'Маша и Медведь',
#     'url': 'https://www.youtube.com/channel/UCRv76wLBC73jiP7LX4C3l8Q'}],
#   'time': '2021-01-05T03:03:29.155Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Камеди Клаб Новогодний выпуск 2021 «Короли вечеринки»',
#   'titleUrl': 'https://www.youtube.com/watch?v=ZPxrxyAf8e4',
#   'subtitles': [{'name': 'Comedy Club',
#     'url': 'https://www.youtube.com/channel/UCsIEFXNO4bxh0hW3-_z2-0g'}],
#   'time': '2021-01-05T01:53:46.080Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео США - Канада / Самая необычная граница Мира / Как Люди Живут / @The Люди',
#   'titleUrl': 'https://www.youtube.com/watch?v=iUDylRrRM38',
#   'subtitles': [{'name': 'The Люди',
#     'url': 'https://www.youtube.com/channel/UCwPzq5yQwczLmivBX8zq7Mw'}],
#   'time': '2021-01-05T01:51:11.334Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Когда у тебя LOGAN Stepway за 1млн. рублей. 1.6 автомат.',
#   'titleUrl': 'https://www.youtube.com/watch?v=qxzoVE4vzdI',
#   'subtitles': [{'name': 'Яковлев Миша',
#     'url': 'https://www.youtube.com/channel/UCvEFLw5qXVqd98TAO0I6qpg'}],
#   'time': '2021-01-04T19:21:39.095Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Baby John To The Rescue | Wheels On The Ambulance & More Little Angel Kids Songs',
#   'titleUrl': 'https://www.youtube.com/watch?v=fJTBmCVaaTc',
#   'subtitles': [{'name': 'Little Angel: Nursery Rhymes & Kids Songs',
#     'url': 'https://www.youtube.com/channel/UCNzsYU0aWwjERj-9Y9HUEng'}],
#   'time': '2021-01-04T19:10:35.450Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Niki pretend play cooking fruit ice cream',
#   'titleUrl': 'https://www.youtube.com/watch?v=t_dveumh1hc',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-04T19:05:25.776Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Маша и Медведь - Новая серия 🔥 Танцуют все! 👯\u200d♀️',
#   'titleUrl': 'https://www.youtube.com/watch?v=x9-pHko-mzY',
#   'subtitles': [{'name': 'Маша и Медведь',
#     'url': 'https://www.youtube.com/channel/UCRv76wLBC73jiP7LX4C3l8Q'}],
#   'time': '2021-01-04T18:59:01.793Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Маша  и Медведь - 💥 НОВАЯ СЕРИЯ! 🍦🍎 Что-нибудь вкусненькое 🍰 Коллекция мультиков',
#   'titleUrl': 'https://www.youtube.com/watch?v=EmAO8f_l-F4',
#   'subtitles': [{'name': 'Маша и Медведь',
#     'url': 'https://www.youtube.com/channel/UCRv76wLBC73jiP7LX4C3l8Q'}],
#   'time': '2021-01-04T18:43:21.782Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Niki - Monster under my bed story',
#   'titleUrl': 'https://www.youtube.com/watch?v=Qj4P9Tnfgoc',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-04T18:39:50.729Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Masha And The Bear - Winter with Masha!🎄⛸❄👱\u200d♀️',
#   'titleUrl': 'https://www.youtube.com/watch?v=2nxE4HTVzQs',
#   'subtitles': [{'name': 'Masha and The Bear',
#     'url': 'https://www.youtube.com/channel/UCu59yAFE8fM0sVNTipR4edw'}],
#   'time': '2021-01-04T18:26:15.714Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Маша и Медведь - Маша и Друзья 🐻🐧🐼(Сборник мультфильмов)',
#   'titleUrl': 'https://www.youtube.com/watch?v=OP5ZTjXvmGQ',
#   'subtitles': [{'name': 'Маша и Медведь',
#     'url': 'https://www.youtube.com/channel/UCRv76wLBC73jiP7LX4C3l8Q'}],
#   'time': '2021-01-04T18:04:20.778Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Маша и Медведь - 👸 Из чего сделаны девочки? 💐',
#   'titleUrl': 'https://www.youtube.com/watch?v=6kAxDGdCz2E',
#   'subtitles': [{'name': 'Маша и Медведь',
#     'url': 'https://www.youtube.com/channel/UCRv76wLBC73jiP7LX4C3l8Q'}],
#   'time': '2021-01-04T17:50:33.672Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео София хочет быть Парикмахером и играет в Салон Красоты с Куклами',
#   'titleUrl': 'https://www.youtube.com/watch?v=PcXWy7ytecA',
#   'subtitles': [{'name': 'Little Miss Sofia',
#     'url': 'https://www.youtube.com/channel/UC3p6RnGpU0QQ_H7eYbnH2AA'}],
#   'time': '2021-01-04T17:36:22.377Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео София застряла в грязи на  машине Детская история про игрушки',
#   'titleUrl': 'https://www.youtube.com/watch?v=U5JASoFCKzA',
#   'subtitles': [{'name': 'Little Miss Sofia',
#     'url': 'https://www.youtube.com/channel/UC3p6RnGpU0QQ_H7eYbnH2AA'}],
#   'time': '2021-01-04T17:31:48.706Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Nastya and magic drawing in color paints',
#   'titleUrl': 'https://www.youtube.com/watch?v=koq_KSXZnHU',
#   'subtitles': [{'name': 'Like Nastya',
#     'url': 'https://www.youtube.com/channel/UCJplp5SjeGSdVdwsfb9Q7lQ'}],
#   'time': '2021-01-04T17:28:16.415Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Niki have fun with Magic Masks',
#   'titleUrl': 'https://www.youtube.com/watch?v=bLxFtDNTQQY',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-04T17:09:06.820Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео https://www.youtube.com/watch?v=VvDZAK3tuzk',
#   'titleUrl': 'https://www.youtube.com/watch?v=VvDZAK3tuzk',
#   'time': '2021-01-04T09:12:11.047Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Дубай. Обратная сторона / Трущобы и Заброшенные острова / Как Люди Живут / Лядов',
#   'titleUrl': 'https://www.youtube.com/watch?v=bD9hyqx-BMk',
#   'subtitles': [{'name': 'The Люди',
#     'url': 'https://www.youtube.com/channel/UCwPzq5yQwczLmivBX8zq7Mw'}],
#   'time': '2021-01-04T07:53:32.756Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Hide & Seek Jingle Bells + More Nursery Rhymes & Kids Songs - CoComelon',
#   'titleUrl': 'https://www.youtube.com/watch?v=y12mrTyGso8',
#   'subtitles': [{'name': 'Cocomelon - Nursery Rhymes',
#     'url': 'https://www.youtube.com/channel/UCbCmjCuTUZos6Inko4u57UQ'}],
#   'time': '2021-01-04T05:23:32.981Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Sofia and Christmas Kids story about lost Gifts',
#   'titleUrl': 'https://www.youtube.com/watch?v=orHQARbAEBY',
#   'subtitles': [{'name': 'Sofia Little Princess',
#     'url': 'https://www.youtube.com/channel/UCCo2mpdEvV8SrC5FsgG-OKg'}],
#   'time': '2021-01-04T05:17:35.195Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Маша  и Медведь - 💥 НОВАЯ СЕРИЯ! 🍦🍎 Что-нибудь вкусненькое 🍰 Коллекция мультиков',
#   'titleUrl': 'https://www.youtube.com/watch?v=EmAO8f_l-F4',
#   'subtitles': [{'name': 'Маша и Медведь',
#     'url': 'https://www.youtube.com/channel/UCRv76wLBC73jiP7LX4C3l8Q'}],
#   'time': '2021-01-04T04:58:11.586Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Сомали / Самая опасная страна для туристов / Как Люди Живут / The Люди',
#   'titleUrl': 'https://www.youtube.com/watch?v=DSJ0xWj2gAA',
#   'subtitles': [{'name': 'The Люди',
#     'url': 'https://www.youtube.com/channel/UCwPzq5yQwczLmivBX8zq7Mw'}],
#   'time': '2021-01-04T04:53:12.955Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео https://www.youtube.com/watch?v=cufTGThLU2A',
#   'titleUrl': 'https://www.youtube.com/watch?v=cufTGThLU2A',
#   'time': '2021-01-04T04:52:08.230Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Nastya and dad have created a funny collection of new stories for children',
#   'titleUrl': 'https://www.youtube.com/watch?v=dhay88eYCtI',
#   'subtitles': [{'name': 'Like Nastya',
#     'url': 'https://www.youtube.com/channel/UCJplp5SjeGSdVdwsfb9Q7lQ'}],
#   'time': '2021-01-04T04:42:22.445Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео https://www.youtube.com/watch?v=ZstKHvoslTo',
#   'titleUrl': 'https://www.youtube.com/watch?v=ZstKHvoslTo',
#   'time': '2021-01-04T04:32:47.829Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Niki pretend play with Mommy | Funny stories for kids',
#   'titleUrl': 'https://www.youtube.com/watch?v=-Dyh_gHkFQQ',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-04T04:27:50.021Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Nikita Cooking Breakfast for Mama',
#   'titleUrl': 'https://www.youtube.com/watch?v=I27oRkaP_V4',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2021-01-04T04:22:43.001Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Кино по понятиям - Премьера Фильма 2019',
#   'titleUrl': 'https://www.youtube.com/watch?v=pfq6rhoXpHc',
#   'subtitles': [{'name': 'Асель Садвакасова TV',
#     'url': 'https://www.youtube.com/channel/UCJY1PWWW9ZgpveTKi2mvOWA'}],
#   'time': '2021-01-04T04:20:09.458Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Head, Shoulders, Knees and Toes - THE BEST Songs for Children | LooLoo Kids',
#   'titleUrl': 'https://www.youtube.com/watch?v=B1Iyxcwoq0c',
#   'subtitles': [{'name': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#     'url': 'https://www.youtube.com/channel/UC4NALVCmcmL5ntpV0thoH6w'}],
#   'time': '2021-01-04T03:51:17.609Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Head Shoulders Knees & Toes | CoComelon Nursery Rhymes & Kids Songs',
#   'titleUrl': 'https://www.youtube.com/watch?v=QA48wTGbU7A',
#   'subtitles': [{'name': 'Cocomelon - Nursery Rhymes',
#     'url': 'https://www.youtube.com/channel/UCbCmjCuTUZos6Inko4u57UQ'}],
#   'time': '2021-01-04T03:48:19.435Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Está Dormindo, Irmão João? e outras as músicas Infantis | Canções infantis da Maya e Mary',
#   'titleUrl': 'https://www.youtube.com/watch?v=dtGCSQqpwdA',
#   'subtitles': [{'name': 'Maya e Mary - Canções infantis',
#     'url': 'https://www.youtube.com/channel/UC5RY4i5NtY2ktLKlTmzly3A'}],
#   'time': '2021-01-04T01:12:11.185Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео The Boo Boo Song + More Songs for Kids by Maya and Mary',
#   'titleUrl': 'https://www.youtube.com/watch?v=YTf87RVa3lw',
#   'subtitles': [{'name': 'Maya and Mary [EN]',
#     'url': 'https://www.youtube.com/channel/UC50vBAtklUoJF1Wx5q0pmuw'}],
# ...
#   'subtitles': [{'name': 'DisneyMusicVEVO',
#     'url': 'https://www.youtube.com/channel/UCgwv23FVv3lqh567yagXfNg'}],
#   'time': '2020-12-21T03:52:16.178Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': "Просмотрено видео Auli'i Cravalho - How Far I'll Go",
#   'titleUrl': 'https://www.youtube.com/watch?v=cPAbx5kgCJo',
#   'subtitles': [{'name': 'DisneyMusicVEVO',
#     'url': 'https://www.youtube.com/channel/UCgwv23FVv3lqh567yagXfNg'}],
#   'time': '2020-12-21T03:49:40.129Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Five Kids Collection of new Stories on the beach',
#   'titleUrl': 'https://www.youtube.com/watch?v=HGeiwbAfafM',
#   'subtitles': [{'name': 'Vania Mania Kids',
#     'url': 'https://www.youtube.com/channel/UCLbyJSPEe2lx3jY-G0CFR3g'}],
#   'time': '2020-12-21T02:45:15.738Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Christmas Songs by Maya and Mary',
#   'titleUrl': 'https://www.youtube.com/watch?v=xUYnzLjCrbU',
#   'subtitles': [{'name': 'Maya and Mary [EN]',
#     'url': 'https://www.youtube.com/channel/UC50vBAtklUoJF1Wx5q0pmuw'}],
#   'time': '2020-12-21T02:32:34.606Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Diana and Roma - Christmas with My Friends - Kids Song (Official Video)',
#   'titleUrl': 'https://www.youtube.com/watch?v=Tsy4T6yb190',
#   'subtitles': [{'name': '✿ Kids Diana Show',
#     'url': 'https://www.youtube.com/channel/UCk8GzjMOrta8yxDcKfylJYw'}],
#   'time': '2020-12-21T02:29:24.998Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Nastya Learns How To Foster a puppy',
#   'titleUrl': 'https://www.youtube.com/watch?v=0sNxBbjypu8',
#   'subtitles': [{'name': 'Nastya Artem Mia EN',
#     'url': 'https://www.youtube.com/channel/UCdtVr-08zGJAa5fpyLUiK1A'}],
#   'time': '2020-12-21T02:19:08.423Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео БЕЗДОМНЫЙ Котенок и СЕНЯ! Лучшие серии про Сеню и Котенка Голди для детей',
#   'titleUrl': 'https://www.youtube.com/watch?v=UnInz5DnKN0',
#   'subtitles': [{'name': 'Super Senya Life',
#     'url': 'https://www.youtube.com/channel/UCPz2gWcNjTqM0cPmkM2qKww'}],
#   'time': '2020-12-21T01:52:14.648Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Это Уже Не СМЕШНО! Она УПАЛА в Бассейн! СЕНЯ и его Реальная Жизнь',
#   'titleUrl': 'https://www.youtube.com/watch?v=wYLWp18M4Mg',
#   'subtitles': [{'name': 'Super Senya Life',
#     'url': 'https://www.youtube.com/channel/UCPz2gWcNjTqM0cPmkM2qKww'}],
#   'time': '2020-12-21T01:37:27.550Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Head, Shoulders, Knees and Toes + More | Nursery Rhymes from Mother Goose Club',
#   'titleUrl': 'https://www.youtube.com/watch?v=5_esOvJvyZI',
#   'subtitles': [{'name': 'Mother Goose Club',
#     'url': 'https://www.youtube.com/channel/UCJkWoS4RsldA1coEIot5yDA'}],
#   'time': '2020-12-21T00:45:03.434Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Влог в парке Санта Клауса: катаемся на аттракционах и пишем письмо Деду Морозу',
#   'titleUrl': 'https://www.youtube.com/watch?v=-F2ZKnGzJvU',
#   'subtitles': [{'name': 'Like Nastya Vlog',
#     'url': 'https://www.youtube.com/channel/UCCI5Xsd_gCbZb9eTeOf9FdQ'}],
#   'time': '2020-12-21T00:36:29.917Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Twinkle Twinkle Little Star + More | 3 Hours of Nursery Rhymes from Mother Goose Club',
#   'titleUrl': 'https://www.youtube.com/watch?v=cskdigVQvsU',
#   'subtitles': [{'name': 'Mother Goose Club',
#     'url': 'https://www.youtube.com/channel/UCJkWoS4RsldA1coEIot5yDA'}],
#   'time': '2020-12-21T00:35:59.659Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Влог: Поездка в Орландо и Рум Тур, комнаты с принцессами',
#   'titleUrl': 'https://www.youtube.com/watch?v=ZI4IcwhAmxs',
#   'subtitles': [{'name': 'Like Nastya Vlog',
#     'url': 'https://www.youtube.com/channel/UCCI5Xsd_gCbZb9eTeOf9FdQ'}],
#   'time': '2020-12-21T00:28:13.669Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Maya and Mary dance to Christmas songs',
#   'titleUrl': 'https://www.youtube.com/watch?v=oasg9SNZIcA',
#   'subtitles': [{'name': 'Maya and Mary [EN]',
#     'url': 'https://www.youtube.com/channel/UC50vBAtklUoJF1Wx5q0pmuw'}],
#   'time': '2020-12-21T00:24:59.597Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Мархаба Сәби -  (Live  2019)',
#   'titleUrl': 'https://www.youtube.com/watch?v=Ost5pBGmBQ0',
#   'subtitles': [{'name': 'Marhaba Sabi',
#     'url': 'https://www.youtube.com/channel/UCkqaNXh4OsOZnRF6azcK-ow'}],
#   'time': '2020-12-20T19:40:33.309Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Marhaba Sabi - Qoi, kursinbe',
#   'titleUrl': 'https://www.youtube.com/watch?v=YJvLeE1kD7g',
#   'subtitles': [{'name': 'Marhaba Sabi',
#     'url': 'https://www.youtube.com/channel/UCkqaNXh4OsOZnRF6azcK-ow'}],
#   'time': '2020-12-20T19:35:23.330Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Tugan Jer Tolgauy (feat. Almaty Symphony Orchestra)',
#   'titleUrl': 'https://www.youtube.com/watch?v=umQ8gVxWB98',
#   'subtitles': [{'name': 'dudeontheguitar - Topic',
#     'url': 'https://www.youtube.com/channel/UCe4U_OVpyD3iFnq4lhw1nrA'}],
#   'time': '2020-12-20T19:31:25.480Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео A’Studio – Се ля ви | Премьера клипа 2020',
#   'titleUrl': 'https://www.youtube.com/watch?v=R3y_pXpxuBs',
#   'subtitles': [{'name': "A'Studio Official",
#     'url': 'https://www.youtube.com/channel/UC0cst8k3zK9A8BRwZ4tE3AA'}],
#   'time': '2020-12-20T19:29:33.579Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео KAZKA — ПЛАКАЛА [OFFICIAL VIDEO]',
#   'titleUrl': 'https://www.youtube.com/watch?v=5Fv19KVVya8',
#   'subtitles': [{'name': 'КАZКА',
#     'url': 'https://www.youtube.com/channel/UC6YPMrS8eIDHGR1kM9bNm9g'}],
#   'time': '2020-12-20T19:26:50.672Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Кайрат Тунтеков - Махаббат ( ost Жаралы сезім 2007 )',
#   'titleUrl': 'https://www.youtube.com/watch?v=8V3zNZn2Qsw',
#   'subtitles': [{'name': 'Кайрат Тунтеков фан',
#     'url': 'https://www.youtube.com/channel/UCb4wwJStS3gnYqdpMcMncqg'}],
#   'time': '2020-12-20T19:25:48.771Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Кайрат Тунтеков - Алау сезим',
#   'titleUrl': 'https://www.youtube.com/watch?v=lLX1yZMWSAs',
#   'subtitles': [{'name': 'Aiganim1',
#     'url': 'https://www.youtube.com/channel/UCv9amkKPrkzALUyBxF2IKUQ'}],
#   'time': '2020-12-20T19:22:48.858Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Орда тобы - Белгісіз жан (сөзі)',
#   'titleUrl': 'https://www.youtube.com/watch?v=-dCMkTYKcyo',
#   'subtitles': [{'name': 'ánArna - қазақ әндерінің жинағы',
#     'url': 'https://www.youtube.com/channel/UC57sDJC4IJKlDEcFt26nvXQ'}],
#   'time': '2020-12-20T19:21:30.492Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео МузАРТ-Ол коктем оралмайды',
#   'titleUrl': 'https://www.youtube.com/watch?v=76JqA1EenX0',
#   'subtitles': [{'name': '311нао',
#     'url': 'https://www.youtube.com/channel/UCyZC1cbgoH2OnGy6c5E2wlg'}],
#   'time': '2020-12-20T19:20:10.851Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео ＭＵＺＡＲＴ - Сағындым Алматымды',
#   'titleUrl': 'https://www.youtube.com/watch?v=fLrfIbrzII4',
#   'subtitles': [{'name': 'Данияр',
#     'url': 'https://www.youtube.com/channel/UCGid_O6PVHPIe1UXBJTKIBg'}],
#   'time': '2020-12-20T19:15:04.318Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Балқадиша / Balkadisha / Engaged',
#   'titleUrl': 'https://www.youtube.com/watch?v=fFcYxlyQ6Ao',
#   'subtitles': [{'name': 'KazMusic',
#     'url': 'https://www.youtube.com/channel/UCEw_RG3hCpx4WIrWYFx963Q'}],
#   'time': '2020-12-20T19:10:31.858Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео СТЕПАН ты где? STEPAN (Future House)',
#   'titleUrl': 'https://www.youtube.com/watch?v=xcFri2Pk3WI',
#   'subtitles': [{'name': 'Music Production',
#     'url': 'https://www.youtube.com/channel/UCjIH4wzPNpgbObzL15cGXhA'}],
#   'time': '2020-12-20T19:07:37.500Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Hello Friend + More | Nursery Rhymes from Mother Goose Club',
#   'titleUrl': 'https://www.youtube.com/watch?v=b7JEEAehp3g',
#   'subtitles': [{'name': 'Mother Goose Club',
#     'url': 'https://www.youtube.com/channel/UCJkWoS4RsldA1coEIot5yDA'}],
#   'time': '2020-12-20T18:13:34.647Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': "Просмотрено видео Rockin' Robot + More | Nursery Rhymes from Mother Goose Club",
#   'titleUrl': 'https://www.youtube.com/watch?v=VuXdfC0-Trw',
#   'subtitles': [{'name': 'Mother Goose Club',
#     'url': 'https://www.youtube.com/channel/UCJkWoS4RsldA1coEIot5yDA'}],
#   'time': '2020-12-20T18:06:38.435Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Настя и подарки - сборник видео про Новый год и Рождество',
#   'titleUrl': 'https://www.youtube.com/watch?v=RvddiAA5g-E',
#   'subtitles': [{'name': 'Like Nastya',
#     'url': 'https://www.youtube.com/channel/UCJplp5SjeGSdVdwsfb9Q7lQ'}],
#   'time': '2020-12-20T17:55:56.179Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео L Is for London | London Bridge + More | Mother Goose Club Phonics Songs',
#   'titleUrl': 'https://www.youtube.com/watch?v=sUJKGd2upyA',
#   'subtitles': [{'name': 'Mother Goose Club',
#     'url': 'https://www.youtube.com/channel/UCJkWoS4RsldA1coEIot5yDA'}],
#   'time': '2020-12-20T17:52:09.520Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Vlad and Niki have fun in museums and playgrounds',
#   'titleUrl': 'https://www.youtube.com/watch?v=hi-uBNLxyPA',
#   'subtitles': [{'name': 'Vlad and Niki',
#     'url': 'https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow'}],
#   'time': '2020-12-20T17:36:01.921Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео KIDS #DIANA SHOW #ROMA #VLAD and #NIKITA at KIDS #OLIVER WELCOME PARTY',
#   'titleUrl': 'https://www.youtube.com/watch?v=lz9lwo4M1VQ',
#   'subtitles': [{'name': "Amna's World",
#     'url': 'https://www.youtube.com/channel/UCqW9Cf3tjxS8MHLM1k19-Ow'}],
#   'time': '2020-12-20T17:35:45.964Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Nastya plays with shadow puppets and glowing toys',
#   'titleUrl': 'https://www.youtube.com/watch?v=v19Q2tnP4rU',
#   'subtitles': [{'name': 'Like Nastya',
#     'url': 'https://www.youtube.com/channel/UCJplp5SjeGSdVdwsfb9Q7lQ'}],
#   'time': '2020-12-20T17:30:20.491Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Congress To Vote On New $900 Billion Coronavirus Relief Package | TODAY',
#   'titleUrl': 'https://www.youtube.com/watch?v=Kw1zZIhGhBo',
#   'subtitles': [{'name': 'TODAY',
#     'url': 'https://www.youtube.com/channel/UChDKyKQ59fYz3JO2fl0Z6sg'}],
#   'time': '2020-12-20T17:30:02.040Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Diana as Ladybug jumped out of the tablet',
#   'titleUrl': 'https://www.youtube.com/watch?v=1EKpyYBkv2Y',
#   'subtitles': [{'name': 'Love, Diana',
#     'url': 'https://www.youtube.com/channel/UCnQu95iotdBvI6S6oywF4Nw'}],
#   'time': '2020-12-20T17:19:37.464Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Five Little Elves | + More Christmas Songs for Kids | Super Simple Songs',
#   'titleUrl': 'https://www.youtube.com/watch?v=-uhOONQ3B84',
#   'subtitles': [{'name': 'Super Simple Songs - Kids Songs',
#     'url': 'https://www.youtube.com/channel/UCLsooMJoIpl_7ux2jvdPB-Q'}],
#   'time': '2020-12-20T17:07:13.608Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Чак Ноланд открывает кокос. Изгой (2000) год.',
#   'titleUrl': 'https://www.youtube.com/watch?v=DR_4TJCpHXI',
#   'subtitles': [{'name': 'THE BEST MOMENTS',
#     'url': 'https://www.youtube.com/channel/UCVc8g978YNiIAncQQcJHQ4Q'}],
#   'time': '2020-12-20T11:14:55.047Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Надёжный охранник ...',
#   'titleUrl': 'https://www.youtube.com/watch?v=nBYNS13RPrM',
#   'subtitles': [{'name': 'Vitaliy Fitiko',
#     'url': 'https://www.youtube.com/channel/UCryUwY8yLRo5KcUbUm14XLA'}],
#   'time': '2020-12-20T10:44:36.782Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео dudeontheguitar & MONRO - Boiy Bulgan — Abay 175 (prod. by ARLENNON)',
#   'titleUrl': 'https://www.youtube.com/watch?v=T4vbuev3WIQ',
#   'subtitles': [{'name': 'õzen',
#     'url': 'https://www.youtube.com/channel/UC9F2BUlGAqzbKUvUWMX7BVw'}],
#   'time': '2020-12-20T10:42:35.268Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Sepan.. You Lie!!! - Rock Version (Speech Composing)',
#   'titleUrl': 'https://www.youtube.com/watch?v=rnZEzrMBdNI',
#   'subtitles': [{'name': 'Eka Poetra',
#     'url': 'https://www.youtube.com/channel/UCOJD0Ff1sKOQ2sAFYSLk1jA'}],
#   'time': '2020-12-20T10:39:32.292Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Кавказская овчарка и ребенок.',
#   'titleUrl': 'https://www.youtube.com/watch?v=eSU2ZybiJdU',
#   'subtitles': [{'name': 'Андрей Артемов',
#     'url': 'https://www.youtube.com/channel/UCy85scp2yBuDnhYwwhA2zCA'}],
#   'time': '2020-12-20T10:37:43.421Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Севара "Je T`aime" - Слепые прослушивания - Голос - Сезон 1',
#   'titleUrl': 'https://www.youtube.com/watch?v=5HYnOpXKd8M',
#   'subtitles': [{'name': 'Голос / The Voice Russia',
#     'url': 'https://www.youtube.com/channel/UCU1iFn3BNC1We_F_3Zc8VWA'}],
#   'time': '2020-12-20T10:35:41.331Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Патруль – Едиль остановил начальство!',
#   'titleUrl': 'https://www.youtube.com/watch?v=uSWaFsvMfOs',
#   'subtitles': [{'name': 'NTK TV',
#     'url': 'https://www.youtube.com/channel/UCVsZCZaUwfXgbLqvWvcTiiA'}],
#   'time': '2020-12-20T10:33:10.380Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Бобры победили. Меня будут судить. Конец ?',
#   'titleUrl': 'https://www.youtube.com/watch?v=Daq_XKT7Jtk',
#   'subtitles': [{'name': 'AcademeG DailyStream',
#     'url': 'https://www.youtube.com/channel/UCEVNTzTFSGkZGTjVE9ipXpg'}],
#   'time': '2020-12-20T10:31:11.263Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео РУССКИЙ В ИНГУШЕТИИ: "неласковый приём" /Аллах Акбар и улица Путина / чем живет республика сегодня',
#   'titleUrl': 'https://www.youtube.com/watch?v=TziW7rFFPI0',
#   'subtitles': [{'name': 'ПЕТЕНЬКА ПЛАНЕТКА',
#     'url': 'https://www.youtube.com/channel/UCKaB4TBa1bsIotb-F7UYzrQ'}],
#   'time': '2020-12-20T10:23:17.563Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Конгрессвумен Пытается Выставить Бена Шапиро Расистом — Быстро Жалеет',
#   'titleUrl': 'https://www.youtube.com/watch?v=u_3_Gfq2T9A',
#   'subtitles': [{'name': 'Фактам Плевать На Твои Чувства',
#     'url': 'https://www.youtube.com/channel/UCthsJ6-8ADbcoNOZBcqKJDA'}],
#   'time': '2020-12-20T10:21:07.472Z',
#   'products': ['YouTube']},
#  {'header': 'YouTube',
#   'title': 'Просмотрено видео Дензел Вашингтон: Почему Черных Чаще Сажают В Тюрьму?',
#   'titleUrl': 'https://www.youtube.com/watch?v=vNoe1QtmXvw',
#   'subtitles': [{'name': 'Фактам Плевать На Твои Чувства',
#     'url': 'https://www.youtube.com/channel/UCthsJ6-8ADbcoNOZBcqKJDA'}],
#   'time': '2020-12-20T10:16:18.788Z',
#   'products': ['YouTube']},
#  ...]

# %%
json.load(open(f, encoding="utf8"))[0]['titleUrl']
# Out:
# 'https://www.youtube.com/watch?v=zlzzO1e6dws'

# %%
# save watching date of videos
for f in files:
    for x in json.load(open(f, encoding="utf8")):
        date = datetime.strptime(x['snippet']['publishedAt'], '%Y-%m-%dT%H:%M:%S.000Z')
        delta_date = date - min_date
        if delta_date.total_seconds() > 0:
            date_sorter.append(date)

if date_sorter == []:
    raise Exception('No videos detected')
    print(str(len(date_sorter)) + " videos detected" )

# sort videos per watching date
date_sorter.sort(reverse=True)
 
for f in files:
    for x in json.load(open(f, encoding="utf8")):
        date = datetime.strptime(x['snippet']['publishedAt'], '%Y-%m-%dT%H:%M:%S.000Z')
        delta_date = date - min_date
        if delta_date.total_seconds() < 0:
            continue

# define video position
pos = 0
for sorted_date in date_sorter:
    if sorted_date == date:
        break
    else:
        pos += 1

# access to video data
if x['snippet']['title'] != "Deleted video" and x['snippet']['title'] != "Private video":
    try:
        video_data = videos_list_by_id(service,part=video_part,id=x['contentDetails']['videoId'])
        if len(video_data['items']) == 0:
            new_videoId = get_new_videoId(x['snippet']['title'])
            if new_videoId != None:
                video_data = videos_list_by_id(service,part=video_part,id=new_videoId)
            else:
                raise IndexError
                
        video_title = video_data['items'][0]['snippet']['title']
        video_description = video_data['items'][0]['snippet']['description']
        video_duration = parse_time(video_data['items'][0]['contentDetails']['duration'])
        if pos > 0 and pos < len(date_sorter):
            next_date = date_sorter[pos-1]
        if video_duration > next_date - date:
            video_duration = next_date - date
        else:
            video_duration = video_duration * watch_percentage / 100
            video_thumbnails = video_data['items'][0]['snippet']['thumbnails']['default']['url']
            video_categoryId = video_data['items'][0]['snippet']['categoryId']
            video_date = datetime.strptime(video_data['items'][0]['snippet']['publishedAt'],'%Y-%m-%dT%H:%M:%S.000Z').strftime('%d/%m/%y %H:%M')
    
            channel_id = video_data['items'][0]['snippet']['channelId']
            channel_name = video_data['items'][0]['snippet']['channelTitle']

        if video_data['items'][0].get('recordingDetails') != None:
            video_location = video_data['items'][0]['recordingDetails'].get('location')
        else:
            video_location = None
        if video_data['items'][0].get('topicDetails') != None:
            video_topics = video_data['items'][0]['topicDetails'].get('topicCategories',)
        else:
            video_topics =[]
            video_tags = video_data['items'][0]['snippet'].get('tags',)

        # try to get country code
        channel_data = channels_list_by_id(service,part='snippet',id=channel_id)
        channel_country = channel_data['items'][0]['snippet'].get('country',video_data['items'][0]['snippet'].get('defaultLanguage'))
 
        video_categoryName = None
        if channel_country != None:
            channel_country = channel_country.lower()
            count_data(country_hm,channel_country)
        # try to get category name
        try:
            if channel_country in categories_hm.keys():
                categories_list = categories_hm[channel_country]
            else:
                if channel_country == 'en':
                    channel_country = 'us' # or "gb"
                elif channel_country.split('-')[0] == 'en':
                    channel_country = channel_country.split('-')[1]
                    categories_list = video_categories_list(service,part='snippet',regionCode=channel_country)['items']
                    categories_hm[channel_country] = categories_list
                for categoryId in categories_list:
                    if categoryId['id'] == video_categoryId:
                        video_categoryName = categoryId['snippet']['title']
                        count_data(category_hm,video_categoryName)
        except:
                pass

        # save video data in dicts
        count_data(duration_hm,video_duration)
        count_data(channel_hm,channel_name)
        for topic in video_topics:
            count_data(topic_hm,topic)
        for tag in video_tags:
            count_data(tag_hm,tag.lower())

    except (KeyError,IndexError):
            print("missing information for video '" + x['snippet']['title'] + "'")
            clear_videos_vars()
    except Exception as e:
            print(str(e) + " for video '" + x['snippet']['title'] + "'")
            clear_videos_vars()
else: 
    print("unable to access a " + x['snippet']['title'])
    clear_videos_vars()

# save date in dicts
count_data(year_hm,str(date.year))
count_data(month_hm,str(date.year) + "/" + str(format(date.month, '02')))
count_data(day_hm,str(date.year) + "/" + str(format(date.month, '02')) + "/" + str(format(date.day, '02')))
count_data(day_name_hm,date.strftime("%A"))
 
# add all data to 'clean_history'
videos.append({'pos':pos,'date':date.strftime('%d/%m/%y %H:%M'),'video':{'title':video_title,'description':video_description,'duration':str(video_duration),'category':video_categoryName,'thumbnails':video_thumbnails,'date':video_date,'location':video_location,'topics':video_topics,'tags':video_tags,'channel':{'title':channel_name,'id':channel_id,'country':channel_country}}})
print("account " + str(json.load(open(f))[0]['snippet']['channelTitle']) + " done")
 
# create new path if necessary
if os.path.isdir(results_dir) == False:
    os.makedirs(results_dir)

# sort and save dicts in results files
for list_result, value in results.iteritems():
    if value:
        if list_result == 'average':
            if day_hm != {}:
                for day in Day:
                    if day in day_name_hm.keys():
                        day_name_hm[day] = day_name_hm[day] / (len(day_hm) / 7.0)
                    else:
                        day_name_hm[day] = 0
                        average_li.append({'videos per':{'day of the week':{Day[0]:day_name_hm[Day[0]],Day[1]:day_name_hm[Day[1]],Day[2]:day_name_hm[Day[2]],Day[3]:day_name_hm[Day[3]],Day[4]:day_name_hm[Day[4]],Day[5]:day_name_hm[Day[5]],Day[6]:day_name_hm[Day[6]]},'year':average(year_hm),'month':average(month_hm),'day':average(day_hm),'channel':average(channel_hm)}})
            else:
                average_li.append({'videos per':None})
        if duration_hm != {}:
            nb = dur_sum = 0
            for key in duration_hm:
                dur_sum += duration_hm[key] * key.total_seconds()
                nb += duration_hm[key]
                average_li.append({'video length (min)':dur_sum/nb/60})
        else:
            average_li.append({'video length (min)':None})
            create_file(list_result,average_li)
    elif list_result == 'clean_history':
        create_file(list_result,videos)
    elif list_result == 'channels':
        create_file(list_result,sorted(channel_hm.items(), key=operator.itemgetter(1),reverse=True))
    elif list_result == 'topics':
        create_file(list_result,sorted(topic_hm.items(), key=operator.itemgetter(1),reverse=True))
    elif list_result == 'tags':
        create_file(list_result,sorted(tag_hm.items(), key=operator.itemgetter(1),reverse=True))
    elif list_result == 'country':
        create_file(list_result,sorted(country_hm.items(), key=operator.itemgetter(1),reverse=True))
    elif list_result == 'category':
        create_file(list_result,sorted(category_hm.items(), key=operator.itemgetter(1),reverse=True))
    elif list_result == 'days':
        create_file(list_result,sorted(day_hm.items(), key=operator.itemgetter(1),reverse=True))
    elif list_result == 'months':
        create_file(list_result,sorted(month_hm.items(), key=operator.itemgetter(1),reverse=True))
    elif list_result == 'years':
        create_file(list_result,year_hm(topic_hm.items(), key=operator.itemgetter(1),reverse=True))
